# %% [markdown]
# # **import konlpy & mecab   -  for colab**
# - Tagger error 시, 런타임 재시작

# %%
#깃허브에서 Mecab-ko 의 코랩 버전을 다운받기
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 138 (delta 26), reused 22 (delta 8), pack-reused 91 (from 1)
# Receiving objects: 100% (138/138), 1.72 MiB | 16.89 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
cd Mecab-ko-for-Google-Colab
# Out:
# /content/Mecab-ko-for-Google-Colab

# %%
#(3분 소요)install 잘 되면 mecab0.996 폴더 생김
# !bash install_mecab-ko_on_colab_light_220429.sh
# Out:
# Installing konlpy.....
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 53.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 28.0 MB/s eta 0:00:00
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2024-10-04 10:55:25--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.142.24, 104.192.142.26, 104.192.142.25, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.142.24|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from konlpy.tag import Mecab
mecab = Mecab()

# %%
#mecab 테스트
mecab.pos('아버지가방에들어가신다')
# Out:
# [('아버지', 'NNG'),
#  ('가', 'JKS'),
#  ('방', 'NNG'),
#  ('에', 'JKB'),
#  ('들어가', 'VV'),
#  ('신다', 'EP+EC')]

# %% [markdown]
# # **Import data**
# - reviews_air
# - reviews2401

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ea6a4d32-e9c9-4fe5-9423-ef0a6c31f461" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea6a4d32-e9c9-4fe5-9423-ef0a6c31f461">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('reviews_combined.xlsx')
df.head()
# Out:
#    Unnamed: 0   카테고리   제조사        모델명                           제품명    구매처  \
# 0           0  공기청정기  LG전자  AS303DWFA  LG전자 퓨리케어 360˚ 플러스 AS303DWFA  엘지이닷컴
# 1           1  공기청정기  LG전자  AS303DWFA  LG전자 퓨리케어 360˚ 플러스 AS303DWFA  엘지이닷컴
# 2           2  공기청정기  LG전자  AS303DWFA  LG전자 퓨리케어 360˚ 플러스 AS303DWFA  엘지이닷컴
# 3           3  공기청정기  LG전자  AS303DWFA  LG전자 퓨리케어 360˚ 플러스 AS303DWFA  엘지이닷컴
# 4           4  공기청정기  LG전자  AS303DWFA  LG전자 퓨리케어 360˚ 플러스 AS303DWFA  엘지이닷컴
#
#            작성일  별점                                                 리뷰
# 0  2024.04.30.   5  오랫동안 갖고 싶었던 제품입니다. 일단 디자인 너무 예쁘고 헤드 부분이 공기질에 따...
# 1  2024.04.24.   5  퓨리케어 정말좋네요~ 많이들 사용하는이유를\n알겠더라구요.소음도 거의없고~ 알아서 ...
# 2  2024.06.08.   5  집안 미세먼지 걱정에 구입을 했습니다. 구입후 미세먼지 뿐만 아니라 냄새까지 잡아주...
# 3  2024.04.15.   5   자동 공기청정 모드로 해놓으면 알아서 공기청정 해줍니다.\n공기가 상쾌해지는 기분이에요
# 4  2024.06.03.   5  강아지가 있고 미세먼지 등 요즘 너무 걱정이여서 구매한 제품이에요~~ 구독으로 했으...

# %%
# '카테고리'가 '공기청정기' 필터링
reviews_air = df[(df['카테고리'] == '공기청정기')][['리뷰','별점']]

reviews_air
# Out:
#                                                      리뷰  별점
# 0     오랫동안 갖고 싶었던 제품입니다. 일단 디자인 너무 예쁘고 헤드 부분이 공기질에 따...   5
# 1     퓨리케어 정말좋네요~ 많이들 사용하는이유를\n알겠더라구요.소음도 거의없고~ 알아서 ...   5
# 2     집안 미세먼지 걱정에 구입을 했습니다. 구입후 미세먼지 뿐만 아니라 냄새까지 잡아주...   5
# 3      자동 공기청정 모드로 해놓으면 알아서 공기청정 해줍니다.\n공기가 상쾌해지는 기분이에요   5
# 4     강아지가 있고 미세먼지 등 요즘 너무 걱정이여서 구매한 제품이에요~~ 구독으로 했으...   5
# ...                                                 ...  ..
# 5963  배송비는 바로 받아놓고 계속 전화도 안받으셨지만... 배송믄 2주 조금 더 걸렸습니...   3
# 5964                                    배송도 빠르고 친절하였습니다   5
# 5965     공기청정기는 lg제품이 최고입니다적당한가격에 구매하여 아껴가며 오래도록 쓰겠 습니다   5
# 5966                              배송도 지정일에 잘왔고 싸게 잘 샀어요   5
# 5967                                      역시LG좋하요♡♡♡♡♡♡   5
#
# [5968 rows x 2 columns]

# %%
# '작성일'을 datetime 형식으로 변환 (형식이 yyyy.mm.dd)
df['작성일'] = pd.to_datetime(df['작성일'], format='%Y.%m.%d.')

# '카테고리'가 '공기청정기'이고 '작성일'이 2024년 01월인 행만 필터링
reviews2401 = df[(df['카테고리'] == '공기청정기') & (df['작성일'].dt.strftime('%Y-%m') == '2024-01')]['리뷰']

reviews2401
# Out:
# 30          산지얼마되지않아바닥파기공사하는데먼지막아줄처음포장비닐기사아저씨가가져가너무너무아쉬워요
# 69                                     좋은 제품 감사합니다. 추천합니다
# 122     새로 입주한 아파트에서 사용하고 있어요.머리도 아프고 눈도 너무 따가웠는데 확실히 ...
# 123     화성으로 이사를하게되어 LG 공기 청정기 추가 구매했습니다.\n작동 소음도 적고 편...
# 124     주변에서 공기청정기는 필수다라는 얘기 많이듣고 사용중인데 확실히 달라요!\n미세먼지...
#                               ...
# 5953                                어제 받았어요 생각보다도 더 좋아요^^
# 5954    배송 일주일 걸렸어요.  생각보다 컸어요… 작동은 잘되요.. 오토모드로 해 놓으면 ...
# 5955                                     잘 사용해 봅시다 그려 ㅋㅋㅋ
# 5962    배송도 빠르고 가격도 저렴히 판매해주셔서 너무 만족합니다제품 하자없이 뛰어난 성능으...
# 5965       공기청정기는 lg제품이 최고입니다적당한가격에 구매하여 아껴가며 오래도록 쓰겠 습니다
# Name: 리뷰, Length: 139, dtype: object

# %% [markdown]
# # **mecab.morphs : 1차원 리스트로 변환**
# - 한 문장을 가져와 형태소로 토큰화 한 단어가 리스트로 저장됨
# - 때문에 결과가 2차원 리스트(예: [["나는", "정말"], ["영화가", "정말", "재밌다"], ....]로 저장됨
# - 다음 작업인 사전과 단어를 매칭 시키기 위해서는 2차원 리스트를 1차원 리스트로 변환해 줘야 함

# %%
tokens = [mecab.morphs(word) for word in reviews2401]

tokens = list(map(lambda x : " ".join(x), tokens))

tokens[:10]
# Out:
# ['산지 얼마 되 지 않 아 바닥 파기 공사 하 는 데 먼지 막 아 줄 처음 포장 비닐 기사 아저씨 가 가져가 너무너무 아쉬워 요',
#  '좋 은 제품 감사 합니다 . 추천 합니다',
#  '새로 입주 한 아파트 에서 사용 하 고 있 어요 . 머리 도 아프 고 눈 도 너무 따가웠 는데 확실히 효과 가 있 어서 너무 만족 해요 .',
#  '화성 으로 이사 를 하 게 되 어 LG 공기 청정기 추가 구매 했 습니다 . 작동 소음 도 적 고 편리 한 기능 이 탑재 해 있 어 사용 성 이 좋 을 것 같 습니다 . 가전 은 역시 LG 입니다 .',
#  '주변 에서 공기 청정기 는 필수 다 라는 얘기 많이 듣 고 사용 중 인데 확실히 달라요 ! 미세먼지 많 은 날 에 돌리 면 공기 좀 상쾌 해진 것 같 구 특히 냄새 ! ! 금방 사라져서 놀랐 어요 ! 아직 애 는 없 지만 애 있 을 때 사용 해도 너무 좋 을 꺼 같 아요 . 완전 만족 입니다 .',
#  '공기 청정기 가 필요 해서 고민 고민 하 다가 구매 했 어요 매장 에서 보 고 저렴 하 게 구매 했 네요 lg 기사 분 이 친절 하 게 사용 방법 과 이쁘 게 설치 해 주 셔서 좋 았 어요',
#  '친정 엄마 께서 이 제품 을 꼭 사 고 싶 어 하 셔서 선물 해 드렸 더니 너무 좋 아 하 시 네요 사용 하 기 편하 고 좋 으시 데요',
#  '소음 은 적 어서 좋 아요 . 냄새 는 깨끗 하 게 잡지 는 못 하 는 것 같 아요 .',
#  '사용 을 해 봐야 알 겠 지만 일단 은 마음 에 들 어요',
#  '생각 했 던 거 보다 엄청 커서 한 자리 차지 하 네요 ~ ㅎ 근데 크 니까 먼지 랑 냄새 도 더 잘 빨 아 들일 거 니까 만족 합니다 그리고 예약 배송 날짜 에 딱 맞 게 설치 해 주 셔서 넘 좋 았 어요 소음 은 크 지 않 고 공기 가 청정 한 기분 이 들 어요 열심히 잘 쓸 게 요 ~^^']

# %% [markdown]
# # **한글 감성어 사전(KNU) 업로드**
# json파일
# - (참고) https://m.blog.naver.com/j7youngh/222966330839
# - (감성어 사전) https://github.com/park1200656/KnuSentiLex/tree/master/KnuSentiLex/data

# %%
import json
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c48f7005-cb88-41e0-b78b-f1a9475992ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c48f7005-cb88-41e0-b78b-f1a9475992ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open('SentiWord_info.json', encoding='utf-8-sig', mode='r') as f:
  SentiWord_info = json.load(f)

sentiword_dic = pd.DataFrame(SentiWord_info)

# %% [markdown]
# # **토큰화된 문장과 감성사전 비교**
# df2401

# %% [markdown]
# 감성사전을 단어와 극성을 변수로 한 데이터프레임 형태로 전환
# - 리뷰 한 문장씩 넣어 문장 내 단어와 감성사전 단어를 매치
# - 존재하면 극성값을 가져오고, 없으면 패스
#
# - 리뷰 문장별 극성값은 문장의 포함된 단어의 극성값 합계로 계산
# - (예) "나는 이 영화가 재밌고 감동적이다"라면, '재밌고'가 +1, 감동적이다 +2점으로 이 문장은 긍정적인 +3점 리뷰로 판단

# %%
#감성사전을 단어와 극성을 변수로 한 데이터프레임 형태로 전환
import pandas as pd

df2401 = pd.DataFrame(columns=("review", "sentiment"))  # 리뷰별 극성을 저장하기 위한 데이터프레임 생성
idx = 0                                             # 다음 리뷰로 넘기기 위한 초기값

for token in tokens:                                # 전체 리뷰에서 문장 하나씩 가져옴
  sentiment = 0                                     # 초기 감성값 0으로 설정
  for i in range(0, len(sentiword_dic)):            # 감성사전의 모든 단어를 하나씩 선택
    if sentiword_dic.word[i] in token:              # 리뷰 문장에 감성 단어가 있는지 확인
      sentiment += int(sentiword_dic.polarity[i])   # 감성단어가 있다면 극성값 합계를 구함.
  df2401.loc[idx] = [token, sentiment]                  # 리뷰별 극성값을 데이터프레임으로 쌓음
  idx += 1                                          # 다름 리뷰 문장으로 넘어감

# %%
df2401
# Out:
#                                                 review  sentiment
# 0    산지 얼마 되 지 않 아 바닥 파기 공사 하 는 데 먼지 막 아 줄 처음 포장 비닐...         -1
# 1                               좋 은 제품 감사 합니다 . 추천 합니다          2
# 2    새로 입주 한 아파트 에서 사용 하 고 있 어요 . 머리 도 아프 고 눈 도 너무 ...         -2
# 3    화성 으로 이사 를 하 게 되 어 LG 공기 청정기 추가 구매 했 습니다 . 작동 ...         -2
# 4    주변 에서 공기 청정기 는 필수 다 라는 얘기 많이 듣 고 사용 중 인데 확실히 달...          0
# ..                                                 ...        ...
# 134                        어제 받 았 어요 생각 보다 도 더 좋 아요 ^^          1
# 135  배송 일 주일 걸렸 어요 . 생각 보다 컸 어요 … 작동 은 잘 되 요 . . 오토...          0
# 136                                  잘 사용 해 봅시다 그려 ㅋㅋㅋ         -1
# 137  배송 도 빠르 고 가격 도 저렴 히 판매 해 주 셔서 너무 만족 합니다 제품 하 자...          3
# 138  공기 청정기 는 lg 제품 이 최고 입니다 적당 한 가격 에 구매 하 여 아껴 가 ...          3
#
# [139 rows x 2 columns]

# %% [markdown]
# # **전처리(1)**

# %% [markdown]
# ## **필요시**

# %%
### 런타임 아웃 방지 (https://dacon.io/forum/405904)
function KeepClicking(){

console.log("Clicking");

document.querySelector("colab-connect-button").click()

}

setInterval(KeepClicking,60000)

# %%
### 필요시 새로운 노트북 마다 이거 넣어주면 가능
import os, sys
from google.colab import drive
drive.mount('/content/drive')

my_path = '/content/package'
save_path = '/content/drive/MyDrive/Colab Notebooks/package'

os.symlink(save_path, my_path)
sys.path.insert(0, my_path)

# %% [markdown]
# ## **필요 패키지 다운**

# %%
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# ...
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to /tmp/pip-req-build-j2o2zh23
#   Running command git clone --filter=blob:none --quiet https://github.com/haven-jeon/PyKoSpacing.git /tmp/pip-req-build-j2o2zh23
#   Resolved https://github.com/haven-jeon/PyKoSpacing.git to commit b32a889cbd10b006d2f4aba118f0cd5b677e2979
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pykospacing: filename=pykospacing-0.5-py3-none-any.whl size=2286920 sha256=65f741a6865ca6db7fdbc20f080fcf60a815e9a23cf7bdf22acb9e9a18bbdc41
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xczrfrpu/wheels/76/b3/33/dda14886ee76b8e53eb05580a14dfcf9145e9eb9d282c53f28
# Successfully built pykospacing
# ...

# %% [markdown]
# ## **중복 및 na 처리**

# %%
#import할 패키지 목록
import re
import pandas as pd
from tqdm import tqdm
from konlpy.tag import Okt
from pykospacing import Spacing
from collections import Counter

# %%
reviews_air
# Out:
#                                                      리뷰  별점
# 0     오랫동안 갖고 싶었던 제품입니다. 일단 디자인 너무 예쁘고 헤드 부분이 공기질에 따...   5
# 1     퓨리케어 정말좋네요~ 많이들 사용하는이유를\n알겠더라구요.소음도 거의없고~ 알아서 ...   5
# 2     집안 미세먼지 걱정에 구입을 했습니다. 구입후 미세먼지 뿐만 아니라 냄새까지 잡아주...   5
# 3      자동 공기청정 모드로 해놓으면 알아서 공기청정 해줍니다.\n공기가 상쾌해지는 기분이에요   5
# 4     강아지가 있고 미세먼지 등 요즘 너무 걱정이여서 구매한 제품이에요~~ 구독으로 했으...   5
# ...                                                 ...  ..
# 5963  배송비는 바로 받아놓고 계속 전화도 안받으셨지만... 배송믄 2주 조금 더 걸렸습니...   3
# 5964                                    배송도 빠르고 친절하였습니다   5
# 5965     공기청정기는 lg제품이 최고입니다적당한가격에 구매하여 아껴가며 오래도록 쓰겠 습니다   5
# 5966                              배송도 지정일에 잘왔고 싸게 잘 샀어요   5
# 5967                                      역시LG좋하요♡♡♡♡♡♡   5
#
# [5968 rows x 2 columns]

# %%
#null값 확인
reviews_air.isnull().sum()
# Out:
# 리뷰    0
# 별점    0
# dtype: int64

# %%
#중복행 확인
duplicates = reviews_air[reviews_air['리뷰'].duplicated(keep=False)]
d = duplicates.sort_values(by='리뷰');d
# Out:
#                                                      리뷰  별점
# 959                                                   .   3
# 1835                                                  .   5
# 1489                             .가성비 대비 공기청정이 잘되는것 같네요   5
# 1488                             .가성비 대비 공기청정이 잘되는것 같네요   5
# 4560  10일 사용 후기입니다가격 대비 성능은 만족하구요오토 모드로 사용해서 알아서 공기 ...   5
# ...                                                 ...  ..
# 4523                                       허ㅏㅓㅠㅊ처ㅓㅏㅜ쳐ㅑㅓ   5
# 3391      화면보다 커요 망설이다 구매했어요 집 공기가 색으로보여서좋아요 올황사는 걱?없어요   5
# 3390      화면보다 커요 망설이다 구매했어요 집 공기가 색으로보여서좋아요 올황사는 걱?없어요   5
# 4327                                   확실히 크고 1등급이라 좋아요   5
# 4624                                   확실히 크고 1등급이라 좋아요   5
#
# [1360 rows x 2 columns]

# %%
# 10자 이상 중복된 행 필터링 및 삭제
duplicates = reviews_air[reviews_air['리뷰'].duplicated(keep=False)]
to_drop = duplicates[duplicates['리뷰'].str.len() >= 10].index
reviews_air = reviews_air.drop(to_drop)

# 인덱스 재배열
reviews_air = reviews_air.reset_index(drop=True);reviews_air
# Out:
#                                                      리뷰  별점
# 0     오랫동안 갖고 싶었던 제품입니다. 일단 디자인 너무 예쁘고 헤드 부분이 공기질에 따...   5
# 1     퓨리케어 정말좋네요~ 많이들 사용하는이유를\n알겠더라구요.소음도 거의없고~ 알아서 ...   5
# 2     집안 미세먼지 걱정에 구입을 했습니다. 구입후 미세먼지 뿐만 아니라 냄새까지 잡아주...   5
# 3      자동 공기청정 모드로 해놓으면 알아서 공기청정 해줍니다.\n공기가 상쾌해지는 기분이에요   5
# 4     강아지가 있고 미세먼지 등 요즘 너무 걱정이여서 구매한 제품이에요~~ 구독으로 했으...   5
# ...                                                 ...  ..
# 4810  배송도 빠르고 가격도 저렴히 판매해주셔서 너무 만족합니다제품 하자없이 뛰어난 성능으...   5
# 4811  배송비는 바로 받아놓고 계속 전화도 안받으셨지만... 배송믄 2주 조금 더 걸렸습니...   3
# 4812                                    배송도 빠르고 친절하였습니다   5
# 4813     공기청정기는 lg제품이 최고입니다적당한가격에 구매하여 아껴가며 오래도록 쓰겠 습니다   5
# 4814                                      역시LG좋하요♡♡♡♡♡♡   5
#
# [4815 rows x 2 columns]

# %% [markdown]
# ## **텍스트 전처리**
# 1. 리뷰에서 영어표현, puncation, 이모티콘은 모두 제거한다. (=한글 표현만 남긴다)
#
# 2. 띄어쓰기 변환기를 통해 띄어쓰기가 되어있지 않은 문장들을 제대로 변환한다.
#
# 3. 형태소 분석기를 통해 각각의 리뷰를 형태소 단위로 분리한다.
#
# 4. 한글자로 되어있는 것 제거
#
# 5. 빈도수가 많은 순으로 정렬 후 의미없는 단어(불용어) 제거
#
# 6. 최소빈도수 이하의 것들은 제거한다.
#
# 7. 잘못 분리 된 의미있는 단어들을 찾아서 사용자 단어 사전에 추가 (ex. 디테일 => 디 + 테일로 분리됨)

# %% [markdown]
# **한글표현만 남기기**
# - 영어, 특수기호 제거

# %%
def extract_word(text):
    hangul = re.compile('[^가-힣]')
    result = hangul.sub(' ', text)
    return result

# %%
print("Before Extraction : ",reviews_air['리뷰'][4814])
print("After Extraction : ", extract_word(reviews_air['리뷰'][4814]))

print("Before Extraction : ",reviews_air['리뷰'][1351])
print("After Extraction : ", extract_word(reviews_air['리뷰'][1351]))
# Out:
# Before Extraction :  역시LG좋하요♡♡♡♡♡♡
# After Extraction :  역시  좋하요
# Before Extraction :  성능좋고 저렴하게 잘샀어요 가전은 LG
# After Extraction :  성능좋고 저렴하게 잘샀어요 가전은

# %%
reviews_air['리뷰'] = reviews_air['리뷰'].apply(lambda x:extract_word(x))
reviews_air
# Out:
#                                                      리뷰  별점
# 0     오랫동안 갖고 싶었던 제품입니다  일단 디자인 너무 예쁘고 헤드 부분이 공기질에 따...   5
# 1     퓨리케어 정말좋네요  많이들 사용하는이유를 알겠더라구요 소음도 거의없고  알아서 자...   5
# 2     집안 미세먼지 걱정에 구입을 했습니다  구입후 미세먼지 뿐만 아니라 냄새까지 잡아주...   5
# 3       자동 공기청정 모드로 해놓으면 알아서 공기청정 해줍니다  공기가 상쾌해지는 기분이에요   5
# 4     강아지가 있고 미세먼지 등 요즘 너무 걱정이여서 구매한 제품이에요   구독으로 했으...   5
# ...                                                 ...  ..
# 4810  배송도 빠르고 가격도 저렴히 판매해주셔서 너무 만족합니다제품 하자없이 뛰어난 성능으...   5
# 4811  배송비는 바로 받아놓고 계속 전화도 안받으셨지만    배송믄  주 조금 더 걸렸습니...   3
# 4812                                    배송도 빠르고 친절하였습니다   5
# 4813     공기청정기는   제품이 최고입니다적당한가격에 구매하여 아껴가며 오래도록 쓰겠 습니다   5
# 4814                                      역시  좋하요         5
#
# [4815 rows x 2 columns]

# %% [markdown]
# **띄어쓰기 고치기**
# - pykospacing 사용
# - 전체 데이터에 사용시 시간 많이 소요됨...

# %%
spacing = Spacing()
print("Before Fixing : ",reviews_air['리뷰'][374])
print("After Fixing : ", spacing(reviews_air['리뷰'][374]))
print("Before Fixing : ",reviews_air['리뷰'][14])
print("After Fixing : ", spacing(reviews_air['리뷰'][14]))
# Out:
# Before Fixing :  모델이 투박해보이긴 합니다 삼성답지 않은  삼성제품
# After Fixing :  모델이 투박해 보이긴 합니다 삼성답지 않은 삼성 제품
# Before Fixing :  흰색으로 디자인 깔끔하고성능 좋아요
# After Fixing :  흰색으로 디자인 깔끔하고 성능 좋아요

# %% [markdown]
# **형태소 분석**
# - Okt 사용
# - mecab 사용 가능(추후 추가)

# %%
okt = Okt()
words = " ".join(reviews_air['리뷰'].tolist())
words = okt.morphs(words,stem=True)

# %%
#여러 리뷰들을 하나의 리스트 원소로 합쳐서 형태소를 분리한 뒤 Counter 객체로 빈도수 확인 예정
words
# Out:
# ['오랫동안',
#  '갖다',
#  '싶다',
#  '제품',
#  '이다',
#  '일단',
#  '디자인',
#  '너무',
#  '예쁘다',
#  '헤드',
#  '부분',
#  '이',
#  '공',
#  '기질',
#  '에',
#  '따르다',
#  '움직이다',
#  '게',
#  '뭔가',
#  '똑똑하다',
#  '관리',
#  '하다',
#  '주다',
#  '기분',
#  '이다',
#  '소음',
#  '도',
#  '없다',
#  '스마트',
#  '한',
#  '제품',
#  '이네',
#  '요',
#  '우리',
#  '집',
#  '상쾌하다',
#  '공',
#  '기질',
#  '맡기다',
#  '보다',
#  '그리고',
#  '설치',
#  '기사',
#  '님',
#  '도',
#  '친절하다',
#  '퓨리',
#  '케어',
#  '정말',
#  '좋다',
#  '많이',
#  '들다',
#  '사용',
#  '하다',
#  '이유',
#  '를',
#  '알다',
#  '소음',
#  '도',
#  '거의',
#  '없다',
#  '알다',
#  '자동',
#  '으로',
#  '실내',
#  '공기',
#  '정화',
#  '해주다',
#  '너무',
#  '좋다',
#  '집안',
#  '미세먼지',
#  '걱정',
#  '에',
#  '구입',
#  '을',
#  '하다',
#  '구입',
#  '후',
#  '미세먼지',
#  '뿐',
#  '만',
#  '아니다',
#  '냄새',
#  '까지',
#  '잡다',
#  '정말',
#  '좋다',
#  '먼저',
#  '구매',
#  '하다',
#  '않다',
#  '걸',
#  '후회',
#  '하다',
#  '자다',
#  '쓰다',
#  '자동',
#  '공기',
#  '청정',
#  '모드',
#  '로',
#  '하다',
#  '알다',
#  '공기',
#  '청정',
#  '해주다',
#  '공기',
#  '가',
#  '상쾌하다',
# ...

# %% [markdown]
# **한글자, 불용어 제거**
# - 한 글자인 것들은 주로 조사가 많았고 그렇지 않아도 대체로 의미없는 단어
# - 필요한 단어 제외 가능

# %%
remove_one_word = [x for x in words if len(x)>1]
# remove_one_word = [x for x in words if len(x)>1 or x=="닉"] <<와 같이 or x =='' 하여 한글자여도 냅둘 것 지정 가능

len(remove_one_word) #개수
# Out:
# 60340

# %%
#collections의 Counter객체를 이용하여 단어별 빈도를 확인
from collections import Counter
frequent = Counter(remove_one_word).most_common();frequent
# Out:
# [('하다', 3581),
#  ('좋다', 2946),
#  ('배송', 1150),
#  ('자다', 1033),
#  ('있다', 987),
#  ('사용', 848),
#  ('제품', 775),
#  ('같다', 728),
#  ('보다', 726),
#  ('되다', 688),
#  ('빠르다', 668),
#  ('구매', 652),
#  ('으로', 565),
#  ('크다', 548),
#  ('가격', 530),
#  ('만족하다', 529),
#  ('받다', 525),
#  ('공기청정기', 508),
#  ('너무', 506),
#  ('공기', 501),
#  ('디자인', 452),
#  ('성능', 447),
#  ('필터', 432),
#  ('생각', 427),
#  ('이다', 426),
#  ('하고', 367),
#  ('소음', 358),
#  ('사다', 342),
#  ('없다', 341),
#  ('구입', 339),
#  ('가성', 335),
#  ('조용하다', 323),
#  ('닉스', 318),
#  ('저렴하다', 315),
#  ('에서', 315),
#  ('쓰다', 304),
#  ('않다', 297),
#  ('작동', 287),
#  ('아주', 285),
#  ('크기', 277),
#  ('감사하다', 248),
#  ('들다', 229),
#  ('오다', 220),
#  ('상품', 217),
#  ('거실', 205),
#  ('이라', 202),
#  ('되어다', 199),
#  ('냄새', 198),
#  ('청정', 195),
#  ('기능', 193),
#  ('미세먼지', 184),
#  ('설치', 178),
#  ('괜찮다', 178),
#  ('편하다', 175),
#  ('많이', 169),
#  ('해주다', 164),
#  ('주문', 163),
#  ('등급', 163),
#  ('고민', 158),
#  ('해보다', 153),
#  ('바퀴', 151),
# ...

# %%
# stopwords(불용어) 파일 업로드
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0e80f488-d8f4-4e28-8076-d09cc807ea77" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e80f488-d8f4-4e28-8076-d09cc807ea77">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open('stopwords.txt', 'r', encoding='cp949') as f:
    list_file = f.readlines()
stopwords = list_file[0].split(",")
remove_stopwords = [x for x in remove_one_word if x not in stopwords]
len(remove_stopwords)
#불용어 제거 후 60000 -> 43167
# Out:
# 43167

# %%
Counter(remove_stopwords).most_common()
#이전보다 의미있는 단어만 남음
# Out:
# [('좋다', 2946),
#  ('배송', 1150),
#  ('자다', 1033),
#  ('사용', 848),
#  ('제품', 775),
#  ('빠르다', 668),
#  ('구매', 652),
#  ('크다', 548),
#  ('가격', 530),
#  ('만족하다', 529),
#  ('공기청정기', 508),
#  ('공기', 501),
#  ('디자인', 452),
#  ('성능', 447),
#  ('필터', 432),
#  ('생각', 427),
#  ('소음', 358),
#  ('사다', 342),
#  ('구입', 339),
#  ('가성', 335),
#  ('조용하다', 323),
#  ('닉스', 318),
#  ('저렴하다', 315),
#  ('쓰다', 304),
#  ('작동', 287),
#  ('아주', 285),
#  ('크기', 277),
#  ('감사하다', 248),
#  ('상품', 217),
#  ('거실', 205),
#  ('냄새', 198),
#  ('청정', 195),
#  ('기능', 193),
#  ('미세먼지', 184),
#  ('설치', 178),
#  ('괜찮다', 178),
#  ('편하다', 175),
#  ('해주다', 164),
#  ('주문', 163),
#  ('등급', 163),
#  ('고민', 158),
#  ('해보다', 153),
#  ('바퀴', 151),
#  ('모드', 150),
#  ('소리', 149),
#  ('마음', 148),
#  ('선물', 142),
#  ('삼성', 142),
#  ('대비', 138),
#  ('기사', 137),
#  ('깔끔하다', 136),
#  ('만족', 135),
#  ('예쁘다', 133),
#  ('추천', 132),
#  ('이쁘다', 128),
#  ('이동', 128),
#  ('먼지', 122),
#  ('놓다', 122),
#  ('잘쓰다', 121),
#  ('사이즈', 120),
# ...

# %%
#빈도수가 1인 것들은 확인 후 제거
for item, count in Counter(remove_stopwords).most_common():
    if count==1:
        print(item)

#인데~ 지금 데이터로는 1번만 나온 단어들이 많으니까 생략!!!
minimum_count = 1
more_than_one_time= []
for i in tqdm(range(len(remove_stopwords))):
    tmp = remove_stopwords[i]
    if remove_stopwords.count(tmp) >= minimum_count:
        more_than_one_time.append(tmp)
# Out:
# 구독
# 있습닌다
# 말고는
# 고등어
# 는데
# 스치다
# 동상
# 파기
# 아저씨
# 호전
# 찍히다
# 에이치
# 몰이
# 계산서
# 발급
# 하부
# 운송
# 입금
# 거만
# 합닏
# 문후
# 다감
# 사하다
# 가정은
# 여윽시
# 다를꼬
# 겉보기
# 오인
# 느커지
# 화성
# 사용성
# 질리다
# 의전
# 조그마하다
# 쌩쌩하다
# 장단점
# 쭈욱
# 데리
# 중형
# 소형
# 시원
# 빨래
# 무릎
# 핑크
# 약풍
# 판넬
# 얼굴
# 표정
# 고온
# 써비스
# 별다르다
# 취짐
# 임신
# 침실협탁
# 올려놓다
# 치인
# 트름
# 기특하다
# 무덥다
# 중고
# 바이바이
# 말뭐
# 뭐함
# 편안함
# 택했어
# 싱즈
# 따로따로
# 요건
# 합치다
# 웹사이트
# 이스
# 아버
# 득달
# 흡연
# 가렵네
# 스퇄
# 돌아다니다
# 제주
# 강츄강츄합니
# 아웃렛
# 파이팅
# 을시
# 길어지다
# 청결
# 우려
# 구석
# 지원이
# 화용
# 친철
# 세부
# 매뉴얼
# 의미
# 제방
# 싱스연결
# 사르다
# 테입
# 고정
# 박리
# 불어
# 떠나다
# 불때
# 지고
# 도크
# 규격
# 래미
# 피아노
# 음악학
# 하고는
# 어짜피
# 마르다
# 준수
# 심리
# 인지도
# 이동식
# 드림
# 노란색
# 연두색
# 창가
# 부근
# 크케
# 디릅
# 다사
# 계약
# 안떨어지다
# 감당
# 초반
# 연동제
# 보류
# 챙기다
# 알뜰하다
# 윗쪽
# 뒤쪽
# 실망하다
# 꿀임
# 찬양
# 시스템
# 놀랫네
# 싼마이
# 지나치다
# 성하다
# 마음먹다
# 이불
# 요키
# 센티
# 청처
# 구배
# 특성
# 우중충하다
# 매치
# 더쌈
# 비템
# 기다림
# 프레
# 가깝다
# 거치
# 직송
# 가능도
# 달려들다
# 죻으네
# 지킴
# 접수
# 비프
# 삼전
# 로지텍
# 재료
# 큼큼
# 효용
# 손님
# 갈기
# 뒷날
# 누루
# 신속
# 들락날락
# 리나
# 그림
# 박해
# 답지
# 표기
# 교처
# 평강
# ...

# %% [markdown]
# **konlpy에 사용자 단어 추가**
# - 추후 필요시 사용
# - colab 환경 기반

# %% [markdown]
# # **(1) 최종 함수로 정리**

# %%
#이전의 save_and_load를 다음과 같이 수정
def save_and_load(dataframe):
    basepath = 'data/'
    dataframe.to_csv(basepath+'파일명으로 수정' , index= False)
    df = pd.read_csv(basepath+'파일명으로 수정')
    df = df.dropna()
    df = df.drop_duplicates()
    df = df.reset_index(drop=True)
    return df

# %%
def load_stopwords():
    with open('data/stopwords.txt', 'r') as f:
        list_file = f.readlines()
    return list_file[0].split(",")

# %%
def extract_word(text):
    hangul = re.compile('[^가-힣]')
    result = hangul.sub(' ', text)
    return result

# %%
def make_wordlist(reviews,stopwords): #reviews = " ".join(data['Review'].tolist())
    print("리뷰들을 모아 분석하는 중입니다.....")
    #정규표현식 적용
    print("데이터 정제 중....")
    words = extract_word(reviews)
    #형태소 추출
    print("형태소 추출 중....")
    words = okt.morphs(words,stem=True)
    #한글자 제거
    print("한글자 제거 중....")
    words = [x for x in words if len(x)>1 or x =='닉']
    #불용어 제거
    print("불용어 제거 중....")
    words = [x for x in remove_one_word if x not in stopwords]
    #최소횟수 미만 제거
    print("의미있는 단어리스트 생성 중....")
    time.sleep(1)
    minimum_count = 3
    final = []
    for i in tqdm(range(len(words))):
        tmp = words[i]
        if words.count(tmp) >= minimum_count:
            final.append(tmp)
    return set(final) #조건을 만족하는 단어 리스트

# %%
def preprocess(text, word_list):
    text = extract_word(text)
    okt = Okt()
    text = okt.morphs(text, stem = True)
    text = [x for x in text if x in word_list]
    return text

# %% [markdown]
# # **전처리(2)**

# %% [markdown]
# ## **CountVectorizer**
# 단어들의 출현빈도로 여러 문서들을 벡터화

# %%
# 한글 형태소 구분하기
from  sklearn.feature_extraction.text import CountVectorizer
from konlpy.tag import Kkma

# %%
kkma = Kkma()
# 명사만 추출하는 토큰화 도구 생성
def myTokenizer(text):
    return kkma.nouns(text)

# %%
bow_kkma = CountVectorizer(tokenizer=myTokenizer)
bow_kkma.fit(remove_stopwords)
#bow_kkma.fit(X_train) # kkma를 기준으로 단어사전 구축
# Out:
# CountVectorizer(tokenizer=<function myTokenizer at 0x782df1b87520>)
